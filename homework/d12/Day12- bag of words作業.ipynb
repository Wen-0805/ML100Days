# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /Users/wen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
len(whole_words)
# Out:
# 2351

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n
    n += 1

# %%
word_index
# Out:
# {'1979': 0,
#  'pancakes': 1,
#  'Four': 2,
#  'station': 3,
#  'stuff': 4,
#  'highlighted': 5,
#  'old': 6,
#  'missed': 7,
#  'thinking': 8,
#  'teamwork': 9,
#  'below': 10,
#  'ways': 11,
#  'pace': 12,
#  'sub-par': 13,
#  'expert/connisseur': 14,
#  'recommend': 15,
#  'Frenchman': 16,
#  'cause': 17,
#  'middle': 18,
#  'decent': 19,
#  'mile': 20,
#  'My': 21,
#  'charming': 22,
#  'got': 23,
#  'struggle': 24,
#  'somethat': 25,
#  'likes': 26,
#  'much': 27,
#  'Scottsdale': 28,
#  'AND': 29,
#  'fry': 30,
#  'LOVED': 31,
#  'Bland': 32,
#  'lived': 33,
#  'Overall': 34,
#  'IT': 35,
#  'cakes': 36,
#  'item': 37,
#  'alone': 38,
#  'greens': 39,
#  'veal': 40,
#  'kids': 41,
#  'moist': 42,
#  'forth': 43,
#  'compliments': 44,
#  'ordering': 45,
#  'somehow': 46,
#  'looks': 47,
#  'asked': 48,
#  'i': 49,
#  'low-key': 50,
#  'perfection': 51,
#  'quantity': 52,
#  'Excalibur': 53,
#  'outstanding': 54,
#  'night': 55,
#  'wine': 56,
#  'attached': 57,
#  'kitchen': 58,
#  'sergeant': 59,
#  'vanilla': 60,
#  'reminded': 61,
#  'Mom': 62,
#  'to-go': 63,
#  '6': 64,
#  'soooo': 65,
#  'REAL': 66,
#  'Kind': 67,
#  'WEAK': 68,
#  'cooking': 69,
#  'mall': 70,
#  'petrified': 71,
#  'dog': 72,
#  '3/4ths': 73,
#  'INCONSIDERATE': 74,
#  '8': 75,
#  'It': 76,
#  'boot': 77,
#  'crêpe': 78,
#  'still': 79,
#  'Vegetarian': 80,
#  'yummy': 81,
#  'hella': 82,
#  "'m": 83,
#  'its': 84,
#  'place': 85,
#  'brother': 86,
#  'yet': 87,
#  'pizza': 88,
#  '...': 89,
#  'Aria': 90,
#  'sause': 91,
#  'ground': 92,
#  'liking': 93,
#  'person': 94,
#  'relationship': 95,
#  'condiment': 96,
#  'kiddos': 97,
#  'apple': 98,
#  'smelled': 99,
#  'wall': 100,
#  'elegantly': 101,
#  'surprise': 102,
#  'unbelievable': 103,
#  'angry': 104,
#  'Palm': 105,
#  'disgusting': 106,
#  'Company': 107,
#  'awkwardly': 108,
#  'glance': 109,
#  'helpful': 110,
#  'ago': 111,
#  'spends': 112,
#  'powdered': 113,
#  'excellent': 114,
#  'MANAGEMENT': 115,
#  'use': 116,
#  'idea': 117,
#  'Each': 118,
#  'over-hip': 119,
#  'suggest': 120,
#  'fill': 121,
#  'mood': 122,
#  'greeted': 123,
#  'regular': 124,
#  'anyone': 125,
#  'IN': 126,
#  'the': 127,
#  'glad': 128,
#  'disappoint': 129,
#  'head': 130,
#  'store': 131,
#  'each': 132,
#  'months': 133,
#  'rare': 134,
#  'paid': 135,
#  'Also': 136,
#  'Special': 137,
#  'waiter': 138,
#  'mussels': 139,
#  'clue': 140,
#  'gave': 141,
#  'biggest': 142,
#  'son': 143,
#  'temp.I': 144,
#  'there': 145,
#  'largely': 146,
#  'NONE': 147,
#  'NO': 148,
#  'Damn': 149,
#  'papers': 150,
#  'gooodd': 151,
#  'affordable': 152,
#  'services': 153,
#  'Luke': 154,
#  'different': 155,
#  'Dog': 156,
#  'Subway': 157,
#  'expected': 158,
#  'poor': 159,
#  'probably': 160,
#  'Buldogis': 161,
#  'opened': 162,
#  'wire': 163,
#  'ESTABLISHMENT': 164,
#  'lots': 165,
#  'muffin': 166,
#  'concept': 167,
#  'her': 168,
#  'changing': 169,
#  'by': 170,
#  'flavored': 171,
#  'many': 172,
#  'hours': 173,
#  'OF': 174,
#  'new': 175,
#  '45': 176,
#  'binge': 177,
#  'caught': 178,
#  'attack': 179,
#  'ambiance': 180,
#  'combination': 181,
#  'hits': 182,
#  'handling': 183,
#  'busy': 184,
#  'packed': 185,
#  'readers': 186,
#  'disrespected': 187,
#  'So': 188,
#  'yellowtail': 189,
#  'realized': 190,
#  'style': 191,
#  'group': 192,
#  'Talk': 193,
#  'banana': 194,
#  'at': 195,
#  'assure': 196,
#  'ever': 197,
#  'amazing': 198,
#  'Nicest': 199,
#  'Hunan': 200,
#  'forever': 201,
#  'started': 202,
#  'man': 203,
#  'workers': 204,
#  'food': 205,
#  'space': 206,
#  'PEOPLE': 207,
#  'salad': 208,
#  'garlic': 209,
#  'review': 210,
#  'spices': 211,
#  'hand': 212,
#  'bucks': 213,
#  'Las': 214,
#  'has': 215,
#  'expectations': 216,
#  'Much': 217,
#  'Steak': 218,
#  'imagination': 219,
#  'APPETIZERS': 220,
#  'coffee': 221,
#  'By': 222,
#  'interesting': 223,
#  'vinegrette': 224,
#  'Worse': 225,
#  'arepas': 226,
#  'Both': 227,
#  'doing': 228,
#  'Chinese': 229,
#  'hearts': 230,
#  'sub': 231,
#  'Seriously': 232,
#  'All': 233,
#  'medium': 234,
#  'spicier': 235,
#  'Tonight': 236,
#  'spicy': 237,
#  'but': 238,
#  'buffet': 239,
#  'surprised': 240,
#  'flavorless': 241,
#  'consistent': 242,
#  'sad': 243,
#  'inexpensive': 244,
#  'disappointing': 245,
#  'just': 246,
#  'which': 247,
#  'Seafood': 248,
#  'covers': 249,
#  'falafels': 250,
#  'acknowledged': 251,
#  'please': 252,
#  'deuchebaggery': 253,
#  'Noca': 254,
#  'imagine': 255,
#  'bug': 256,
#  'Just': 257,
#  'loved': 258,
#  'chef': 259,
#  'Similarly': 260,
#  'friend': 261,
#  'Phoenix': 262,
#  'thing': 263,
#  'does': 264,
#  'running': 265,
#  'Up': 266,
#  'However': 267,
#  'service': 268,
#  'menu/': 269,
#  'iced': 270,
#  'Point': 271,
#  'owner': 272,
#  'pleasant': 273,
#  'venue': 274,
#  'placed': 275,
#  'Then': 276,
#  'hip': 277,
#  'Must': 278,
#  'sorely': 279,
#  'Never': 280,
#  'deliciously': 281,
#  'letdown': 282,
#  'nude': 283,
#  'brick': 284,
#  'Rock': 285,
#  'bone': 286,
#  'order': 287,
#  'hot': 288,
#  'Mediocre': 289,
#  'unwrapped': 290,
#  'tartare': 291,
#  'qualified': 292,
#  'GO': 293,
#  'combo': 294,
#  'portion': 295,
#  'bakery': 296,
#  '7': 297,
#  'anytime': 298,
#  'unwelcome': 299,
#  'outdoor': 300,
#  'exquisite': 301,
#  'long': 302,
#  'did': 303,
#  'Flower': 304,
#  'high': 305,
#  'anymore': 306,
#  'inside': 307,
#  'gristle': 308,
#  'WAAAAAAyyyyyyyyyy': 309,
#  'polite': 310,
#  'seasoned': 311,
#  'meet': 312,
#  'soooooo': 313,
#  'damn': 314,
#  '?': 315,
#  'sugar': 316,
#  '40min': 317,
#  'check': 318,
#  'really': 319,
#  'rowdy': 320,
#  'building': 321,
#  'Mediterranean': 322,
#  'killer': 323,
#  'works': 324,
#  'ask': 325,
#  'sit-down': 326,
#  '(': 327,
#  'great': 328,
#  'vegan/veggie': 329,
#  'Panna': 330,
#  'college': 331,
#  'connoisseur': 332,
#  'avocado': 333,
#  '11.99': 334,
#  'passed': 335,
#  'tater': 336,
#  'Salad': 337,
#  'lovely': 338,
#  'indoor': 339,
#  'plethora': 340,
#  'duck': 341,
#  'lover': 342,
#  'mojitos': 343,
#  'carbs': 344,
#  'things': 345,
#  'because': 346,
#  'speedy': 347,
#  'number': 348,
#  'desired': 349,
#  'rest': 350,
#  'down': 351,
#  'worries': 352,
#  'corporation': 353,
#  'whole': 354,
#  'bloodiest': 355,
#  'dirty-': 356,
#  'Join': 357,
#  'driving': 358,
#  'chips': 359,
#  'note': 360,
#  'deal': 361,
#  'joke': 362,
#  'soundtrack': 363,
#  'burned': 364,
#  'nutshell': 365,
#  'club': 366,
#  'informative': 367,
#  'unexperienced': 368,
#  'songs': 369,
#  'cheesecurds': 370,
#  'pop': 371,
#  'bowl': 372,
#  'nachos': 373,
#  'Voodoo': 374,
#  'real': 375,
#  'company': 376,
#  'baklava': 377,
#  'arriving': 378,
#  'disgust': 379,
#  'styrofoam': 380,
#  'beef': 381,
#  'reason': 382,
#  'refried': 383,
#  'duo': 384,
#  'Every': 385,
#  'been-stepped-in-and-tracked-everywhere': 386,
#  'worst/annoying': 387,
#  'garden': 388,
#  'Hut': 389,
#  'into': 390,
#  'disappointed': 391,
#  'wo': 392,
#  'priced': 393,
#  'cranberry': 394,
#  'going': 395,
#  'better': 396,
#  'added': 397,
#  'bagels': 398,
#  'Lobster': 399,
#  'satisfying': 400,
#  'blue': 401,
#  'pizzas': 402,
#  'free': 403,
#  'poured': 404,
#  'if': 405,
#  'so': 406,
#  'beans': 407,
#  'Ordered': 408,
#  'family': 409,
#  'Host': 410,
#  'hands-down': 411,
#  'foot': 412,
#  'Gold': 413,
#  'SHOULD': 414,
#  'eggplant': 415,
#  'trimmed': 416,
#  'human': 417,
#  'least': 418,
#  'effort': 419,
#  'dinner': 420,
#  'milkshake': 421,
#  'Heart': 422,
#  'min': 423,
#  'eat': 424,
#  'reasonable': 425,
#  'grocery': 426,
#  'Pho': 427,
#  'hurry': 428,
#  'positive': 429,
#  'wonderful': 430,
#  'onion': 431,
#  'The': 432,
#  'godfathers': 433,
#  'Roll': 434,
#  'people': 435,
#  'self': 436,
#  'stayed': 437,
#  'Baba': 438,
#  'Frozen': 439,
#  'reviewing': 440,
#  'our': 441,
#  'Im': 442,
#  'reduction': 443,
#  'Ironman': 444,
#  'restaurants': 445,
#  'see': 446,
#  'saffron': 447,
#  'chicken': 448,
#  'blandest': 449,
#  'come': 450,
#  'anticipated': 451,
#  'plus': 452,
#  'Everyone': 453,
#  'seafood': 454,
#  'while': 455,
#  'pumpkin': 456,
#  'older': 457,
#  'happened': 458,
#  'dark': 459,
#  'be': 460,
#  'continue': 461,
#  'smoothies': 462,
#  '....': 463,
#  'airline': 464,
#  'SCREAMS': 465,
#  'become': 466,
#  'mess': 467,
#  'gem': 468,
#  'vegetables': 469,
#  'everything': 470,
#  'puree': 471,
#  'Cape': 472,
#  'experiencing': 473,
#  'enjoyable': 474,
#  'when': 475,
#  'Please': 476,
#  'Burger': 477,
#  'parties': 478,
#  'truffle': 479,
#  'enjoy': 480,
#  'Weird': 481,
#  'waiting': 482,
#  'providing': 483,
#  'taco': 484,
#  'cannoli': 485,
#  'Tasty': 486,
#  'shops': 487,
#  'summarize': 488,
#  'decide': 489,
#  'peach': 490,
#  'Outstanding': 491,
#  'Food': 492,
#  'unhealthy': 493,
#  'Waitress': 494,
#  'it': 495,
#  'golden-crispy': 496,
#  'little': 497,
#  'That': 498,
#  'crispy': 499,
#  'eating': 500,
#  'spice': 501,
#  'shots': 502,
#  'Halibut': 503,
#  'served': 504,
#  'hamburger': 505,
#  'generic': 506,
#  'end': 507,
#  'hardly': 508,
#  'Honestly': 509,
#  'stood': 510,
#  'area/': 511,
#  'find': 512,
#  'Thumbs': 513,
#  'heard': 514,
#  'CONCLUSION': 515,
#  'Denny': 516,
#  'approval': 517,
#  'since': 518,
#  'Burrittos': 519,
#  'slices': 520,
#  'rushed': 521,
#  'beyond': 522,
#  'feel': 523,
#  'job': 524,
#  'OK': 525,
#  'shocked': 526,
#  'occasional': 527,
#  'walked': 528,
#  'mouths': 529,
#  'relleno': 530,
#  'orders': 531,
#  'fun': 532,
#  'Avoid': 533,
#  'uninspired': 534,
#  'spot': 535,
#  'Ganoush': 536,
#  'Paying': 537,
#  'Seat': 538,
#  'provides': 539,
#  'that': 540,
#  'arrived': 541,
#  'impressed': 542,
#  '1': 543,
#  'paper': 544,
#  'getting': 545,
#  "n't": 546,
#  'array': 547,
#  'Wife': 548,
#  'held': 549,
#  'Bean': 550,
#  'mediocre': 551,
#  'boxes': 552,
#  'complaints': 553,
#  'shawarrrrrrma': 554,
#  'Waited': 555,
#  'succulent': 556,
#  'marrow': 557,
#  'screwed': 558,
#  'tribute': 559,
#  'Today': 560,
#  'He': 561,
#  'hoping': 562,
#  'awesome': 563,
#  'Shrimp-': 564,
#  'ladies': 565,
#  'par': 566,
#  'ate': 567,
#  ')': 568,
#  'week': 569,
#  'holiday': 570,
#  'delight': 571,
#  'grease': 572,
#  'they': 573,
#  'We': 574,
#  'Bar': 575,
#  'want': 576,
#  'honestly': 577,
#  'Update': 578,
#  'pleased': 579,
#  'operation': 580,
#  'stomach': 581,
#  'prompt': 582,
#  'honest': 583,
#  'pissd': 584,
#  'patio': 585,
#  'love': 586,
#  'email': 587,
#  'receives': 588,
#  'shoe': 589,
#  'dish': 590,
#  'serving': 591,
#  'Tigerlilly': 592,
#  'Stars': 593,
#  'low': 594,
#  'ahead': 595,
#  'inspired': 596,
#  'bits': 597,
#  'thanks': 598,
#  'tell': 599,
#  'biscuits': 600,
#  'two': 601,
#  'topic': 602,
#  'looked': 603,
#  'tops': 604,
#  'events': 605,
#  'judge': 606,
#  'tenders': 607,
#  'rating': 608,
#  'she': 609,
#  'instantly': 610,
#  'sucks': 611,
#  'You': 612,
#  'TIME': 613,
#  'silently': 614,
#  'croutons': 615,
#  'Classy/warm': 616,
#  'six': 617,
#  'meatloaf': 618,
#  'serivce': 619,
#  'blown': 620,
#  'spinach': 621,
#  'WORST': 622,
#  'itself': 623,
#  'kid': 624,
#  'fo': 625,
#  'authentic': 626,
#  'ethic': 627,
#  '35': 628,
#  'hit': 629,
#  'bite': 630,
#  'Nothing': 631,
#  'LEGIT': 632,
#  'an': 633,
#  'Yama': 634,
#  '10': 635,
#  'circumstances': 636,
#  'Although': 637,
#  'mains': 638,
#  'cover': 639,
#  'RI': 640,
#  'raspberry': 641,
#  'deserves': 642,
#  'recall': 643,
#  'Over': 644,
#  'tolerance': 645,
#  'friendly': 646,
#  'thirty': 647,
#  'fat': 648,
#  'postinos': 649,
#  'Cibo': 650,
#  'beat': 651,
#  'sides': 652,
#  '..': 653,
#  '!': 654,
#  'Honeslty': 655,
#  'indicate': 656,
#  'weekly': 657,
#  'full': 658,
#  'An': 659,
#  'once': 660,
#  'roast': 661,
#  'Chicken': 662,
#  'mid': 663,
#  'contain': 664,
#  'Caballero': 665,
#  'HAVE': 666,
#  'large': 667,
#  'places': 668,
#  'Hiro': 669,
#  'touch': 670,
#  'Ramsey': 671,
#  'delicate': 672,
#  'for': 673,
#  'managed': 674,
#  'EXPERIENCE': 675,
#  'businesses': 676,
#  'stretch': 677,
#  'tender': 678,
#  'mention': 679,
#  'no': 680,
#  'Not': 681,
#  'platter': 682,
#  'swung': 683,
#  '12': 684,
#  'chickens': 685,
#  'inflate': 686,
#  'opinion': 687,
#  'ohhh': 688,
#  'Your': 689,
#  'cold': 690,
#  'quick': 691,
#  'dropped': 692,
#  'leaves': 693,
#  'Indian': 694,
#  'Smashburger': 695,
#  'T.': 696,
#  'Google': 697,
#  'non-fancy': 698,
#  'Bellagio': 699,
#  'deep': 700,
#  'AYCE': 701,
#  'section': 702,
#  'establishment': 703,
#  'too': 704,
#  'over': 705,
#  'mouth': 706,
#  'Some': 707,
#  'falling': 708,
#  'pack': 709,
#  'describing': 710,
#  'pita': 711,
#  'heart': 712,
#  'smaller': 713,
#  'Costco': 714,
#  'margaritas': 715,
#  'menu': 716,
#  'spots': 717,
#  'crowds': 718,
#  'then': 719,
#  'Maine': 720,
#  'mesquite': 721,
#  'Everything': 722,
#  'Hard': 723,
#  'On': 724,
#  'staying': 725,
#  'location': 726,
#  'close': 727,
#  'hospitality': 728,
#  'fail': 729,
#  'received': 730,
#  'gone': 731,
#  'Back': 732,
#  'plate': 733,
#  'downtown': 734,
#  'inch': 735,
#  'familiar': 736,
#  'mayo': 737,
#  'strangers': 738,
#  'HOUR': 739,
#  'hummus': 740,
#  'known': 741,
#  'eggs': 742,
#  'One': 743,
#  'customer': 744,
#  'unprofessional': 745,
#  'suck': 746,
#  'myself': 747,
#  'living': 748,
#  'like': 749,
#  'bottom': 750,
#  'judging': 751,
#  'must': 752,
#  'right': 753,
#  'poisoning': 754,
#  'white': 755,
#  'who': 756,
#  'Those': 757,
#  'am': 758,
#  'considering': 759,
#  'blow': 760,
#  'tomato': 761,
#  'super': 762,
#  'slow': 763,
#  'yukon': 764,
#  'restaurant': 765,
#  'seriously': 766,
#  'Thus': 767,
#  'Wonderful': 768,
#  'chocolate': 769,
#  'Rice': 770,
#  'Worst': 771,
#  'Reasonably': 772,
#  'putting': 773,
#  'bars': 774,
#  'Insults': 775,
#  'Needless': 776,
#  'Gyros': 777,
#  'generous': 778,
#  'prices': 779,
#  'climbing': 780,
#  'say': 781,
#  'disgusted': 782,
#  'is': 783,
#  'warnings': 784,
#  'leave': 785,
#  'watch': 786,
#  'Yelpers': 787,
#  'capers': 788,
#  'vegetarian': 789,
#  'year': 790,
#  'bellies': 791,
#  'tasted': 792,
#  'handled': 793,
#  'was': 794,
#  '/hand': 795,
#  'spaghetti': 796,
#  'due': 797,
#  'undercooked': 798,
#  'Friend': 799,
#  'desserts': 800,
#  'almonds': 801,
#  'pricing': 802,
#  'ensued': 803,
#  'tap': 804,
#  'will': 805,
#  'came': 806,
#  '2007': 807,
#  'convenient': 808,
#  'char': 809,
#  'such': 810,
#  'fairly': 811,
#  'Francisco': 812,
#  'lightly': 813,
#  'dreamed': 814,
#  'waitress': 815,
#  'oven': 816,
#  'lunch': 817,
#  'sitting': 818,
#  'know': 819,
#  'If': 820,
#  'chow': 821,
#  'piece': 822,
#  'break': 823,
#  'fan': 824,
#  'hereas': 825,
#  'theft': 826,
#  'someone': 827,
#  'were': 828,
#  'greatest': 829,
#  'wound': 830,
#  'neat': 831,
#  'insulted': 832,
#  'also': 833,
#  'fabulous': 834,
#  'quickly': 835,
#  'Sunday': 836,
#  'MUST': 837,
#  'spring': 838,
#  'words': 839,
#  'cafe': 840,
#  'signs': 841,
#  'writing': 842,
#  'vacant': 843,
#  'overpriced': 844,
#  'wildly': 845,
#  'wow': 846,
#  'fish': 847,
#  'market': 848,
#  'send': 849,
#  'ordered': 850,
#  'bartender': 851,
#  'After': 852,
#  'opportunity': 853,
#  'gratitude': 854,
#  'disgrace': 855,
#  'Very': 856,
#  'avoid': 857,
#  'dry': 858,
#  'mein': 859,
#  'entire': 860,
#  'OMG': 861,
#  'twice': 862,
#  'proclaimed': 863,
#  "ya'all": 864,
#  'cheeseburger': 865,
#  'other': 866,
#  'Egg': 867,
#  'grow': 868,
#  'decorated': 869,
#  'non-customer': 870,
#  'Dos': 871,
#  'supposed': 872,
#  'immediately': 873,
#  'nothing': 874,
#  'fresh': 875,
#  'room': 876,
#  'Han': 877,
#  'reheated': 878,
#  'rapidly': 879,
#  'containers': 880,
#  'dead': 881,
#  'finish': 882,
#  'NASTY': 883,
#  'couples': 884,
#  'THIS': 885,
#  '23': 886,
#  'uploaded': 887,
#  '4.00': 888,
#  'sucked': 889,
#  'boys': 890,
#  'pats': 891,
#  'meh': 892,
#  'apart': 893,
#  'tasteless': 894,
#  'OVERPRICED': 895,
#  'enjoyed': 896,
#  'ridiculous': 897,
#  'more': 898,
#  'military': 899,
#  'RUDE': 900,
#  'coming': 901,
#  'drinks': 902,
#  'hankering': 903,
#  '--': 904,
#  'wait': 905,
#  'WHAT': 906,
#  'properly': 907,
#  'interior': 908,
#  'Thai': 909,
#  'vinaigrette': 910,
#  'vain': 911,
#  'bring': 912,
#  'cuisine': 913,
#  'doubt': 914,
#  'needed': 915,
#  'Nice': 916,
#  'drawing': 917,
#  'Jeff': 918,
#  'joy': 919,
#  'pork': 920,
#  'She': 921,
#  'thumbs': 922,
#  'mozzarella': 923,
#  'modern': 924,
#  'front': 925,
#  'Terrible': 926,
#  'guest': 927,
#  '7.85': 928,
#  '5': 929,
#  'WILL': 930,
#  '1.5lb': 931,
#  '$': 932,
#  'sucker': 933,
#  'First': 934,
#  'Bay': 935,
#  'milk': 936,
#  "''": 937,
#  'definately': 938,
#  'pasta': 939,
#  'thinly': 940,
#  'guests': 941,
#  'sure': 942,
#  '.': 943,
#  'dusted': 944,
#  'plantains': 945,
#  'Overpriced': 946,
#  'attitudes': 947,
#  'show': 948,
#  'downright': 949,
#  'return': 950,
#  'eyes': 951,
#  'luck': 952,
#  'course': 953,
#  'liked': 954,
#  'typical': 955,
#  'seasonal': 956,
#  'included': 957,
#  'Albondigas': 958,
#  'my': 959,
#  'Come': 960,
#  'THAT': 961,
#  'totally': 962,
#  'one': 963,
#  'Fantastic': 964,
#  'Hawaiian': 965,
#  'rich': 966,
#  'Love': 967,
#  'went': 968,
#  'owners': 969,
#  'Pros': 970,
#  'manager': 971,
#  'tacos': 972,
#  'meals': 973,
#  'sticks': 974,
#  'BARGAIN': 975,
#  'brings': 976,
#  'visit': 977,
#  'gold': 978,
#  '......': 979,
#  'asking': 980,
#  'Perfect': 981,
#  'believe': 982,
#  'others': 983,
#  'ache': 984,
#  'home': 985,
#  'dirty': 986,
#  'witnessed': 987,
#  'chewy': 988,
#  'genuinely': 989,
#  'dont': 990,
#  'Bisque': 991,
#  'sals': 992,
#  'forgetting': 993,
#  'Check': 994,
#  'loving': 995,
#  'horrible': 996,
#  'lacked': 997,
#  'reminds': 998,
#  'beers': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: '.',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  19: '.',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  23: 'the',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  32: 'and',
#  33: 'loved',
#  34: 'it',
#  35: '.',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  39: 'the',
#  40: 'menu',
#  41: 'was',
#  42: 'great',
#  43: 'and',
#  44: 'so',
#  45: 'were',
#  46: 'the',
#  47: 'prices',
#  48: '.',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  54: 'and',
#  55: 'I',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  60: '.',
#  61: 'Honeslty',
#  62: 'it',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
#  68: '.',
#  69: ')',
#  70: 'The',
#  71: 'potatoes',
#  72: 'were',
#  73: 'like',
#  74: 'rubber',
#  75: 'and',
#  76: 'you',
#  77: 'could',
#  78: 'tell',
#  79: 'they',
#  80: 'had',
#  81: 'been',
#  82: 'made',
#  83: 'up',
#  84: 'ahead',
#  85: 'of',
#  86: 'time',
#  87: 'being',
#  88: 'kept',
#  89: 'under',
#  90: 'a',
#  91: 'warmer',
#  92: '.',
#  93: 'The',
#  94: 'fries',
#  95: 'were',
#  96: 'great',
#  97: 'too',
#  98: '.',
#  99: 'A',
#  100: 'great',
#  101: 'touch',
#  102: '.',
#  103: 'Service',
#  104: 'was',
#  105: 'very',
#  106: 'prompt',
#  107: '.',
#  108: 'Would',
#  109: 'not',
#  110: 'go',
#  111: 'back',
#  112: '.',
#  113: 'The',
#  114: 'cashier',
#  115: 'had',
#  116: 'no',
#  117: 'care',
#  118: 'what',
#  119: 'so',
#  120: 'ever',
#  121: 'on',
#  122: 'what',
#  123: 'I',
#  124: 'had',
#  125: 'to',
#  126: 'say',
#  127: 'it',
#  128: 'still',
#  129: 'ended',
#  130: 'up',
#  131: 'being',
#  132: 'wayyy',
#  133: 'overpriced',
#  134: '.',
#  135: 'I',
#  136: 'tried',
#  137: 'the',
#  138: 'Cape',
#  139: 'Cod',
#  140: 'ravoli',
#  141: ',',
#  142: 'chicken',
#  143: ',',
#  144: 'with',
#  145: 'cranberry',
#  146: '...',
#  147: 'mmmm',
#  148: '!',
#  149: 'I',
#  150: 'was',
#  151: 'disgusted',
#  152: 'because',
#  153: 'I',
#  154: 'was',
#  155: 'pretty',
#  156: 'sure',
#  157: 'that',
#  158: 'was',
#  159: 'human',
#  160: 'hair',
#  161: '.',
#  162: 'I',
#  163: 'was',
#  164: 'shocked',
#  165: 'because',
#  166: 'no',
#  167: 'signs',
#  168: 'indicate',
#  169: 'cash',
#  170: 'only',
#  171: '.',
#  172: 'Highly',
#  173: 'recommended',
#  174: '.',
#  175: 'Waitress',
#  176: 'was',
#  177: 'a',
#  178: 'little',
#  179: 'slow',
#  180: 'in',
#  181: 'service',
#  182: '.',
#  183: 'This',
#  184: 'place',
#  185: 'is',
#  186: 'not',
#  187: 'worth',
#  188: 'your',
#  189: 'time',
#  190: ',',
#  191: 'let',
#  192: 'alone',
#  193: 'Vegas',
#  194: '.',
#  195: 'did',
#  196: 'not',
#  197: 'like',
#  198: 'at',
#  199: 'all',
#  200: '.',
#  201: 'The',
#  202: 'Burrittos',
#  203: 'Blah',
#  204: '!',
#  205: 'The',
#  206: 'food',
#  207: ',',
#  208: 'amazing',
#  209: '.',
#  210: 'Service',
#  211: 'is',
#  212: 'also',
#  213: 'cute',
#  214: '.',
#  215: 'I',
#  216: 'could',
#  217: 'care',
#  218: 'less',
#  219: '...',
#  220: 'The',
#  221: 'interior',
#  222: 'is',
#  223: 'just',
#  224: 'beautiful',
#  225: '.',
#  226: 'So',
#  227: 'they',
#  228: 'performed',
#  229: '.',
#  230: 'That',
#  231: "'s",
#  232: 'right',
#  233: '...',
#  234: '.the',
#  235: 'red',
#  236: 'velvet',
#  237: 'cake',
#  238: '...',
#  239: '..ohhh',
#  240: 'this',
#  241: 'stuff',
#  242: 'is',
#  243: 'so',
#  244: 'good',
#  245: '.',
#  246: '-',
#  247: 'They',
#  248: 'never',
#  249: 'brought',
#  250: 'a',
#  251: 'salad',
#  252: 'we',
#  253: 'asked',
#  254: 'for',
#  255: '.',
#  256: 'This',
#  257: 'hole',
#  258: 'in',
#  259: 'the',
#  260: 'wall',
#  261: 'has',
#  262: 'great',
#  263: 'Mexican',
#  264: 'street',
#  265: 'tacos',
#  266: ',',
#  267: 'and',
#  268: 'friendly',
#  269: 'staff',
#  270: '.',
#  271: 'Took',
#  272: 'an',
#  273: 'hour',
#  274: 'to',
#  275: 'get',
#  276: 'our',
#  277: 'food',
#  278: 'only',
#  279: '4',
#  280: 'tables',
#  281: 'in',
#  282: 'restaurant',
#  283: 'my',
#  284: 'food',
#  285: 'was',
#  286: 'Luke',
#  287: 'warm',
#  288: ',',
#  289: 'Our',
#  290: 'sever',
#  291: 'was',
#  292: 'running',
#  293: 'around',
#  294: 'like',
#  295: 'he',
#  296: 'was',
#  297: 'totally',
#  298: 'overwhelmed',
#  299: '.',
#  300: 'The',
#  301: 'worst',
#  302: 'was',
#  303: 'the',
#  304: 'salmon',
#  305: 'sashimi',
#  306: '.',
#  307: 'Also',
#  308: 'there',
#  309: 'are',
#  310: 'combos',
#  311: 'like',
#  312: 'a',
#  313: 'burger',
#  314: ',',
#  315: 'fries',
#  316: ',',
#  317: 'and',
#  318: 'beer',
#  319: 'for',
#  320: '23',
#  321: 'which',
#  322: 'is',
#  323: 'a',
#  324: 'decent',
#  325: 'deal',
#  326: '.',
#  327: 'This',
#  328: 'was',
#  329: 'like',
#  330: 'the',
#  331: 'final',
#  332: 'blow',
#  333: '!',
#  334: 'I',
#  335: 'found',
#  336: 'this',
#  337: 'place',
#  338: 'by',
#  339: 'accident',
#  340: 'and',
#  341: 'I',
#  342: 'could',
#  343: 'not',
#  344: 'be',
#  345: 'happier',
#  346: '.',
#  347: 'seems',
#  348: 'like',
#  349: 'a',
#  350: 'good',
#  351: 'quick',
#  352: 'place',
#  353: 'to',
#  354: 'grab',
#  355: 'a',
#  356: 'bite',
#  357: 'of',
#  358: 'some',
#  359: 'familiar',
#  360: 'pub',
#  361: 'food',
#  362: ',',
#  363: 'but',
#  364: 'do',
#  365: 'yourself',
#  366: 'a',
#  367: 'favor',
#  368: 'and',
#  369: 'look',
#  370: 'elsewhere',
#  371: '.',
#  372: 'Overall',
#  373: ',',
#  374: 'I',
#  375: 'like',
#  376: 'this',
#  377: 'place',
#  378: 'a',
#  379: 'lot',
#  380: '.',
#  381: 'The',
#  382: 'only',
#  383: 'redeeming',
#  384: 'quality',
#  385: 'of',
#  386: 'the',
#  387: 'restaurant',
#  388: 'was',
#  389: 'that',
#  390: 'it',
#  391: 'was',
#  392: 'very',
#  393: 'inexpensive',
#  394: '.',
#  395: 'Ample',
#  396: 'portions',
#  397: 'and',
#  398: 'good',
#  399: 'prices',
#  400: '.',
#  401: 'Poor',
#  402: 'service',
#  403: ',',
#  404: 'the',
#  405: 'waiter',
#  406: 'made',
#  407: 'me',
#  408: 'feel',
#  409: 'like',
#  410: 'I',
#  411: 'was',
#  412: 'stupid',
#  413: 'every',
#  414: 'time',
#  415: 'he',
#  416: 'came',
#  417: 'to',
#  418: 'the',
#  419: 'table',
#  420: '.',
#  421: 'My',
#  422: 'first',
#  423: 'visit',
#  424: 'to',
#  425: 'Hiro',
#  426: 'was',
#  427: 'a',
#  428: 'delight',
#  429: '!',
#  430: 'Service',
#  431: 'sucks',
#  432: '.',
#  433: 'The',
#  434: 'shrimp',
#  435: 'tender',
#  436: 'and',
#  437: 'moist',
#  438: '.',
#  439: 'There',
#  440: 'is',
#  441: 'not',
#  442: 'a',
#  443: 'deal',
#  444: 'good',
#  445: 'enough',
#  446: 'that',
#  447: 'would',
#  448: 'drag',
#  449: 'me',
#  450: 'into',
#  451: 'that',
#  452: 'establishment',
#  453: 'again',
#  454: '.',
#  455: 'Hard',
#  456: 'to',
#  457: 'judge',
#  458: 'whether',
#  459: 'these',
#  460: 'sides',
#  461: 'were',
#  462: 'good',
#  463: 'because',
#  464: 'we',
#  465: 'were',
#  466: 'grossed',
#  467: 'out',
#  468: 'by',
#  469: 'the',
#  470: 'melted',
#  471: 'styrofoam',
#  472: 'and',
#  473: 'did',
#  474: "n't",
#  475: 'want',
#  476: 'to',
#  477: 'eat',
#  478: 'it',
#  479: 'for',
#  480: 'fear',
#  481: 'of',
#  482: 'getting',
#  483: 'sick',
#  484: '.',
#  485: 'On',
#  486: 'a',
#  487: 'positive',
#  488: 'note',
#  489: ',',
#  490: 'our',
#  491: 'server',
#  492: 'was',
#  493: 'very',
#  494: 'attentive',
#  495: 'and',
#  496: 'provided',
#  497: 'great',
#  498: 'service',
#  499: '.',
#  500: 'Frozen',
#  501: 'pucks',
#  502: 'of',
#  503: 'disgust',
#  504: ',',
#  505: 'with',
#  506: 'some',
#  507: 'of',
#  508: 'the',
#  509: 'worst',
#  510: 'people',
#  511: 'behind',
#  512: 'the',
#  513: 'register',
#  514: '.',
#  515: 'The',
#  516: 'only',
#  517: 'thing',
#  518: 'I',
#  519: 'did',
#  520: 'like',
#  521: 'was',
#  522: 'the',
#  523: 'prime',
#  524: 'rib',
#  525: 'and',
#  526: 'dessert',
#  527: 'section',
#  528: '.',
#  529: 'It',
#  530: "'s",
#  531: 'too',
#  532: 'bad',
#  533: 'the',
#  534: 'food',
#  535: 'is',
#  536: 'so',
#  537: 'damn',
#  538: 'generic',
#  539: '.',
#  540: 'The',
#  541: 'burger',
#  542: 'is',
#  543: 'good',
#  544: 'beef',
#  545: ',',
#  546: 'cooked',
#  547: 'just',
#  548: 'right',
#  549: '.',
#  550: 'If',
#  551: 'you',
#  552: 'want',
#  553: 'a',
#  554: 'sandwich',
#  555: 'just',
#  556: 'go',
#  557: 'to',
#  558: 'any',
#  559: 'Firehouse',
#  560: '!',
#  561: '!',
#  562: '!',
#  563: '!',
#  564: '!',
#  565: 'My',
#  566: 'side',
#  567: 'Greek',
#  568: 'salad',
#  569: 'with',
#  570: 'the',
#  571: 'Greek',
#  572: 'dressing',
#  573: 'was',
#  574: 'so',
#  575: 'tasty',
#  576: ',',
#  577: 'and',
#  578: 'the',
#  579: 'pita',
#  580: 'and',
#  581: 'hummus',
#  582: 'was',
#  583: 'very',
#  584: 'refreshing',
#  585: '.',
#  586: 'We',
#  587: 'ordered',
#  588: 'the',
#  589: 'duck',
#  590: 'rare',
#  591: 'and',
#  592: 'it',
#  593: 'was',
#  594: 'pink',
#  595: 'and',
#  596: 'tender',
#  597: 'on',
#  598: 'the',
#  599: 'inside',
#  600: 'with',
#  601: 'a',
#  602: 'nice',
#  603: 'char',
#  604: 'on',
#  605: 'the',
#  606: 'outside',
#  607: '.',
#  608: 'He',
#  609: 'came',
#  610: 'running',
#  611: 'after',
#  612: 'us',
#  613: 'when',
#  614: 'he',
#  615: 'realized',
#  616: 'my',
#  617: 'husband',
#  618: 'had',
#  619: 'left',
#  620: 'his',
#  621: 'sunglasses',
#  622: 'on',
#  623: 'the',
#  624: 'table',
#  625: '.',
#  626: 'Their',
#  627: 'chow',
#  628: 'mein',
#  629: 'is',
#  630: 'so',
#  631: 'good',
#  632: '!',
#  633: 'They',
#  634: 'have',
#  635: 'horrible',
#  636: 'attitudes',
#  637: 'towards',
#  638: 'customers',
#  639: ',',
#  640: 'and',
#  641: 'talk',
#  642: 'down',
#  643: 'to',
#  644: 'each',
#  645: 'one',
#  646: 'when',
#  647: 'customers',
#  648: 'do',
#  649: "n't",
#  650: 'enjoy',
#  651: 'their',
#  652: 'food',
#  653: '.',
#  654: 'The',
#  655: 'portion',
#  656: 'was',
#  657: 'huge',
#  658: '!',
#  659: 'Loved',
#  660: 'it',
#  661: '...',
#  662: 'friendly',
#  663: 'servers',
#  664: ',',
#  665: 'great',
#  666: 'food',
#  667: ',',
#  668: 'wonderful',
#  669: 'and',
#  670: 'imaginative',
#  671: 'menu',
#  672: '.',
#  673: 'The',
#  674: 'Heart',
#  675: 'Attack',
#  676: 'Grill',
#  677: 'in',
#  678: 'downtown',
#  679: 'Vegas',
#  680: 'is',
#  681: 'an',
#  682: 'absolutely',
#  683: 'flat-lined',
#  684: 'excuse',
#  685: 'for',
#  686: 'a',
#  687: 'restaurant',
#  688: '.',
#  689: 'Not',
#  690: 'much',
#  691: 'seafood',
#  692: 'and',
#  693: 'like',
#  694: '5',
#  695: 'strings',
#  696: 'of',
#  697: 'pasta',
#  698: 'at',
#  699: 'the',
#  700: 'bottom',
#  701: '.',
#  702: 'The',
#  703: 'salad',
#  704: 'had',
#  705: 'just',
#  706: 'the',
#  707: 'right',
#  708: 'amount',
#  709: 'of',
#  710: 'sauce',
#  711: 'to',
#  712: 'not',
#  713: 'over',
#  714: 'power',
#  715: 'the',
#  716: 'scallop',
#  717: ',',
#  718: 'which',
#  719: 'was',
#  720: 'perfectly',
#  721: 'cooked',
#  722: '.',
#  723: 'The',
#  724: 'ripped',
#  725: 'banana',
#  726: 'was',
#  727: 'not',
#  728: 'only',
#  729: 'ripped',
#  730: ',',
#  731: 'but',
#  732: 'petrified',
#  733: 'and',
#  734: 'tasteless',
#  735: '.',
#  736: 'At',
#  737: 'least',
#  738: 'think',
#  739: 'to',
#  740: 'refill',
#  741: 'my',
#  742: 'water',
#  743: 'before',
#  744: 'I',
#  745: 'struggle',
#  746: 'to',
#  747: 'wave',
#  748: 'you',
#  749: 'over',
#  750: 'for',
#  751: '10',
#  752: 'minutes',
#  753: '.',
#  754: 'This',
#  755: 'place',
#  756: 'receives',
#  757: 'stars',
#  758: 'for',
#  759: 'their',
#  760: 'APPETIZERS',
#  761: '!',
#  762: '!',
#  763: '!',
#  764: 'The',
#  765: 'cocktails',
#  766: 'are',
#  767: 'all',
#  768: 'handmade',
#  769: 'and',
#  770: 'delicious',
#  771: '.',
#  772: 'We',
#  773: "'d",
#  774: 'definitely',
#  775: 'go',
#  776: 'back',
#  777: 'here',
#  778: 'again',
#  779: '.',
#  780: 'We',
#  781: 'are',
#  782: 'so',
#  783: 'glad',
#  784: 'we',
#  785: 'found',
#  786: 'this',
#  787: 'place',
#  788: '.',
#  789: 'Great',
#  790: 'food',
#  791: 'and',
#  792: 'service',
#  793: ',',
#  794: 'huge',
#  795: 'portions',
#  796: 'and',
#  797: 'they',
#  798: 'give',
#  799: 'a',
#  800: 'military',
#  801: 'discount',
#  802: '.',
#  803: 'Always',
#  804: 'a',
#  805: 'great',
#  806: 'time',
#  807: 'at',
#  808: 'Dos',
#  809: 'Gringos',
#  810: '!',
#  811: 'Update',
#  812: '...',
#  813: '..went',
#  814: 'back',
#  815: 'for',
#  816: 'a',
#  817: 'second',
#  818: 'time',
#  819: 'and',
#  820: 'it',
#  821: 'was',
#  822: 'still',
#  823: 'just',
#  824: 'as',
#  825: 'amazing',
#  826: 'We',
#  827: 'got',
#  828: 'the',
#  829: 'food',
#  830: 'and',
#  831: 'apparently',
#  832: 'they',
#  833: 'have',
#  834: 'never',
#  835: 'heard',
#  836: 'of',
#  837: 'salt',
#  838: 'and',
#  839: 'the',
#  840: 'batter',
#  841: 'on',
#  842: 'the',
#  843: 'fish',
#  844: 'was',
#  845: 'chewy',
#  846: '.',
#  847: 'A',
#  848: 'great',
#  849: 'way',
#  850: 'to',
#  851: 'finish',
#  852: 'a',
#  853: 'great',
#  854: '.',
#  855: 'The',
#  856: 'deal',
#  857: 'included',
#  858: '5',
#  859: 'tastings',
#  860: 'and',
#  861: '2',
#  862: 'drinks',
#  863: ',',
#  864: 'and',
#  865: 'Jeff',
#  866: 'went',
#  867: 'above',
#  868: 'and',
#  869: 'beyond',
#  870: 'what',
#  871: 'we',
#  872: 'expected',
#  873: '.',
#  874: '-',
#  875: 'Really',
#  876: ',',
#  877: 'really',
#  878: 'good',
#  879: 'rice',
#  880: ',',
#  881: 'all',
#  882: 'the',
#  883: 'time',
#  884: '.',
#  885: 'The',
#  886: 'service',
#  887: 'was',
#  888: 'meh',
#  889: '.',
#  890: 'It',
#  891: 'took',
#  892: 'over',
#  893: '30',
#  894: 'min',
#  895: 'to',
#  896: 'get',
#  897: 'their',
#  898: 'milkshake',
#  899: ',',
#  900: 'which',
#  901: 'was',
#  902: 'nothing',
#  903: 'more',
#  904: 'than',
#  905: 'chocolate',
#  906: 'milk',
#  907: '.',
#  908: 'I',
#  909: 'guess',
#  910: 'I',
#  911: 'should',
#  912: 'have',
#  913: 'known',
#  914: 'that',
#  915: 'this',
#  916: 'place',
#  917: 'would',
#  918: 'suck',
#  919: ',',
#  920: 'because',
#  921: 'it',
#  922: 'is',
#  923: 'inside',
#  924: 'of',
#  925: 'the',
#  926: 'Excalibur',
#  927: ',',
#  928: 'but',
#  929: 'I',
#  930: 'did',
#  931: "n't",
#  932: 'use',
#  933: 'my',
#  934: 'common',
#  935: 'sense',
#  936: '.',
#  937: 'The',
#  938: 'scallop',
#  939: 'dish',
#  940: 'is',
#  941: 'quite',
#  942: 'appalling',
#  943: 'for',
#  944: 'value',
#  945: 'as',
#  946: 'well',
#  947: '.',
#  948: '2',
#  949: 'times',
#  950: '-',
#  951: 'Very',
#  952: 'Bad',
#  953: 'Customer',
#  954: 'Service',
#  955: '!',
#  956: 'The',
#  957: 'sweet',
#  958: 'potato',
#  959: 'fries',
#  960: 'were',
#  961: 'very',
#  962: 'good',
#  963: 'and',
#  964: 'seasoned',
#  965: 'well',
#  966: '.',
#  967: 'Today',
#  968: 'is',
#  969: 'the',
#  970: 'second',
#  971: 'time',
#  972: 'I',
#  973: "'ve",
#  974: 'been',
#  975: 'to',
#  976: 'their',
#  977: 'lunch',
#  978: 'buffet',
#  979: 'and',
#  980: 'it',
#  981: 'was',
#  982: 'pretty',
#  983: 'good',
#  984: '.',
#  985: 'There',
#  986: 'is',
#  987: 'so',
#  988: 'much',
#  989: 'good',
#  990: 'food',
#  991: 'in',
#  992: 'Vegas',
#  993: 'that',
#  994: 'I',
#  995: 'feel',
#  996: 'cheated',
#  997: 'for',
#  998: 'wasting',
#  999: 'an',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros([len(whole_words),])
    
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
